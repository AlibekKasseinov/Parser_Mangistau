# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd

# %%
file_path_city = "/content/Мангистауская область.xlsx"
df_city = pd.read_excel(file_path_city)
id_list_city = df_city['business_id'].astype(str).str.zfill(12)
df_city['id_list']=id_list_city

# %%
df_city
# Out:
#       business_id                                   business_name_ru  \
# 0       540003765  ГОСУДАРСТВЕННОЕ КОММУНАЛЬНОЕ КАЗЕННОЕ ПРЕДПРИЯ...
# 1       740001627  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛ...
# 2       740001637  ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛЬНАЯ ОБЩЕОБРА...
# 3       740001667  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 4       840001492  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 14' ОТДЕЛА ОБ...
# ..            ...                                                ...
# 591  991040003457  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 592  991040003467  КГУ 'НАЧАЛЬНАЯ ШКОЛА №5' ОТДЕЛА ОБРАЗОВАНИЯ ПО...
# 593  991040003516  КГУ «НАЧАЛЬНАЯ ШКОЛА БЕКИ» ОТДЕЛА ОБРАЗОВАНИЯ ...
# 594  991040003685  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ С.ЖАНГАБЫ...
# 595  991140005070  КГУ «ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ АБИША КЕК...
#
#     oked_level_0 oked_level_1                            oked_level_2  \
# ...

# %%
file_path_village = "/content/Мангистауская область.xlsx"
df_village = pd.read_excel(file_path_village)
id_list_village = df_village['business_id'].astype(str).str.zfill(12)
df_village['id_list']=id_list_village

# %%
df_village
# Out:
#       business_id                                   business_name_ru  \
# 0       540003765  ГОСУДАРСТВЕННОЕ КОММУНАЛЬНОЕ КАЗЕННОЕ ПРЕДПРИЯ...
# 1       740001627  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛ...
# 2       740001637  ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛЬНАЯ ОБЩЕОБРА...
# 3       740001667  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 4       840001492  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 14' ОТДЕЛА ОБ...
# ..            ...                                                ...
# 591  991040003457  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 592  991040003467  КГУ 'НАЧАЛЬНАЯ ШКОЛА №5' ОТДЕЛА ОБРАЗОВАНИЯ ПО...
# 593  991040003516  КГУ «НАЧАЛЬНАЯ ШКОЛА БЕКИ» ОТДЕЛА ОБРАЗОВАНИЯ ...
# 594  991040003685  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ С.ЖАНГАБЫ...
# 595  991140005070  КГУ «ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ АБИША КЕК...
#
#     oked_level_0 oked_level_1                            oked_level_2  \
# ...

# %%
data_city = []
for id_city in id_list_city:
    url = f'https://pk.uchet.kz/search/bin/{id_city}'
    response = requests.get(url)
    soup = BS(response.text, 'html.parser')
    address_item_elements = soup.find_all('div', class_='info-block__object-block')

    for address_item in address_item_elements:
        # Access the first element (index 0)
        city_div = address_item_elements[0]

        # Now you can manipulate the elements as needed
        print(city_div.get_text())

        data_city.append(city_div.get_text())
# Out:
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г.ФОРТ-ШЕВЧЕНКО, УЛИЦА МАРШАЛ АБДИХАЛЫКОВ, 10/1
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г.ФОРТ-ШЕВЧЕНКО, УЛИЦА МАРШАЛ АБДИХАЛЫКОВ, 10/1
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Микрорайон Шугыла, строение 21Д
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Микрорайон Шугыла, строение 21Д
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Станция Станция Вокзал, строение 8Б
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Станция Станция Вокзал, строение 8Б
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИЙ С.О., С. ТЕНГЕ, УЛИЦА АКТАН КЕРЕЙУЛЫ, 40А
# МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИЙ С.О., С. ТЕНГЕ, УЛИЦА АКТАН КЕРЕЙУЛЫ, 40А
# МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕНЕКСКИЙ С.О., С.АККУДУК, УЛИЦА НЕ ОПРЕДЕЛЕН, 50
# МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕНЕКСКИЙ С.О., С.АККУДУК, УЛИЦА НЕ ОПРЕДЕЛЕН, 50
# МАНГИСТАУСКАЯ ОБЛАСТЬ, АКТАУ Г.А., Г.АКТАУ, МИКРОРАЙОН 3Б, 4
# ...

# %%
data_city
# Out:
# ['МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г.ФОРТ-ШЕВЧЕНКО, УЛИЦА МАРШАЛ АБДИХАЛЫКОВ, 10/1',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г.ФОРТ-ШЕВЧЕНКО, УЛИЦА МАРШАЛ АБДИХАЛЫКОВ, 10/1',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Микрорайон Шугыла, строение 21Д',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Микрорайон Шугыла, строение 21Д',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Станция Станция Вокзал, строение 8Б',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗЕН, Станция Станция Вокзал, строение 8Б',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИЙ С.О., С. ТЕНГЕ, УЛИЦА АКТАН КЕРЕЙУЛЫ, 40А',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИЙ С.О., С. ТЕНГЕ, УЛИЦА АКТАН КЕРЕЙУЛЫ, 40А',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕНЕКСКИЙ С.О., С.АККУДУК, УЛИЦА НЕ ОПРЕДЕЛЕН, 50',
#  'МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕНЕКСКИЙ С.О., С.АККУДУК, УЛИЦА НЕ ОПРЕДЕЛЕН, 50',
# ...

# %%
df_city_addresses = pd.DataFrame({'Column_Name': data_city})

# %%
df_city_addresses = df_city_addresses[df_city_addresses.ne(df_city_addresses.shift()).any(axis=1)]
df_city.reset_index(drop=True, inplace=True)

# %%
df_city_addresses
# Out:
#                                             Column_Name
# 0     МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г...
# 2     МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 4     МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 6     МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИ...
# 8     МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕН...
# ...                                                 ...
# 1164  МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Б...
# 1166  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ШЕ...
# 1168  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
# 1170  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ТУ...
# 1172  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
#
# [578 rows x 1 columns]

# %%
excel_file_path = 'df_city_addresses.xlsx'
df_city_addresses.to_excel(excel_file_path, index=False)

# %%
path = '/content/df_city_addresses.xlsx'
df_city_addresses_cleaned = pd.read_excel(path)

# %%
df_city_addresses_cleaned
# Out:
#                                            Column_Name
# 0    МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г...
# 1    МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 2    МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 3    МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИ...
# 4    МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕН...
# ..                                                 ...
# 573  МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Б...
# 574  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ШЕ...
# 575  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
# 576  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ТУ...
# 577  МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
#
# [578 rows x 1 columns]

# %%
city_addresses_cleaned=df_city_addresses_cleaned['Column_Name']
city_addresses_cleaned
# Out:
# 0      МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Г...
# 1      МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 2      МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., Г.ЖАНАОЗ...
# 3      МАНГИСТАУСКАЯ ОБЛАСТЬ, ЖАНАОЗЕН Г.А., ТЕНГЕСКИ...
# 4      МАНГИСТАУСКАЯ ОБЛАСТЬ, КАРАКИЯНСКИЙ РАЙОН, СЕН...
#                              ...
# 573    МАНГИСТАУСКАЯ ОБЛАСТЬ, ТУПКАРАГАНСКИЙ РАЙОН, Б...
# 574    МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ШЕ...
# 575    МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
# 576    МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ТУ...
# 577    МАНГИСТАУСКАЯ ОБЛАСТЬ, МАНГИСТАУСКИЙ РАЙОН, ОН...
# Name: Column_Name, Length: 578, dtype: object

# %%
from geopy.geocoders import GoogleV3

latitude_list_city = []
longitude_list_city = []

# Initialize the geocoder with your API key
geolocator = GoogleV3(api_key="AIzaSyBXjkIPspaWtTqv9uZT1nkYkUt2o6dQZOM", domain="maps.google.ru")

# Geocode each address in the list
for address in city_addresses_cleaned:
    location = geolocator.geocode(address)
    if location:
        print(f"Address: {location.address}")
        print(f"Latitude: {location.latitude}, Longitude: {location.longitude}")
        print("-" * 30)
        latitude_list_city.append(location.latitude)
        longitude_list_city.append(location.longitude)
    else:
        print(f"Geocoding failed for address: {address}")
        print("-" * 30)
# Out:
# Address: Форт-Шевченко, Казахстан
# Latitude: 44.5075526, Longitude: 50.2624052
# ------------------------------
# Address: Жанаозен, Казахстан
# Latitude: 43.357629, Longitude: 52.8434912
# ------------------------------
# Address: Жанаозен, Казахстан
# Latitude: 43.357629, Longitude: 52.8434912
# ------------------------------
# Address: Теңге, Жаңаөзен, Казахстан
# Latitude: 43.352009, Longitude: 52.870178
# ------------------------------
# Address: Аккудук, Казахстан
# Latitude: 42.971355, Longitude: 54.09676
# ------------------------------
# Address: 3-Б микрорайон, Актау, Казахстан
# Latitude: 43.6400691, Longitude: 51.1817558
# ------------------------------
# Address: здание 8, микрорайон 4, Актау, Казахстан
# Latitude: 43.6869392, Longitude: 51.1614465
# ------------------------------
# Address: здание 25, микрорайон 29, Казахстан
# Latitude: 43.6852425, Longitude: 51.1621855
# ------------------------------
# Address: Бейнеу, Казахстан
# ...

# %%
len(latitude_list_city)
# Out:
# 541

# %%
print(len(df_city))
print(len(latitude_list_city))
print(len(longitude_list_city))
# Out:
# 596
# 541
# 541

# %%
df_city['latitudess'] = latitude_series
df_city['longitudess'] = longitude_series

# %%
df_city
# Out:
#       business_id                                   business_name_ru  \
# 0       540003765  ГОСУДАРСТВЕННОЕ КОММУНАЛЬНОЕ КАЗЕННОЕ ПРЕДПРИЯ...
# 1       740001627  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛ...
# 2       740001637  ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'НАЧАЛЬНАЯ ОБЩЕОБРА...
# 3       740001667  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 4       840001492  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА № 14' ОТДЕЛА ОБ...
# ..            ...                                                ...
# 591  991040003457  КОММУНАЛЬНОЕ ГОСУДАРСТВЕННОЕ УЧРЕЖДЕНИЕ 'ШКОЛА...
# 592  991040003467  КГУ 'НАЧАЛЬНАЯ ШКОЛА №5' ОТДЕЛА ОБРАЗОВАНИЯ ПО...
# 593  991040003516  КГУ «НАЧАЛЬНАЯ ШКОЛА БЕКИ» ОТДЕЛА ОБРАЗОВАНИЯ ...
# 594  991040003685  КГУ 'ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ С.ЖАНГАБЫ...
# 595  991140005070  КГУ «ОБЩЕОБРАЗОВАТЕЛЬНАЯ ШКОЛА ИМЕНИ АБИША КЕК...
#
#     oked_level_0 oked_level_1                            oked_level_2  \
# ...
